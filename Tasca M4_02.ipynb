# %%
#Fes les tasques de preprocessat  i adequació del Dataset que disposem en el repositori de GitHub PRE-PROCESSING-DATA amb l'objectiu de preparar-lo i treballar-lo com a dataframe per a extreure'n informació.

import pandas as pd
df=pd.read_csv("movies.csv",encoding='latin-1', header=None, delimiter=";")
df.head()
# Out:
#    0                             1     2          3
# 0  1                    Toy Story   1995  Animation
# 1  2                      Jumanji   1995  Adventure
# 2  3             Grumpier Old Men   1995     Comedy
# 3  4            Waiting to Exhale   1995     Comedy
# 4  5  Father of the Bride Part II   1995     Comedy

# %%
# Mostra la teva creativitat. Què creus rellevant mostrar del Dataset "movies.dat" de l'exercici anterior?
# Fes una o dues representacions gràfiques i justifica la teva elecció.

import matplotlib.pyplot as plt


df2=df.groupby(3).count()
df2.head()
myplot=df2.plot(kind="bar")
myplot.grid()
myplot.set_title("Nº películes segons gènere")
myplot.text(-3,-600,"Aquest gràfic permet veure quin gènere aglutina una major quantitat de películes",bbox = dict(facecolor = 'red', alpha = 0.5))
plt.show()

# %%
import matplotlib.ticker as ticker
import pylab as plb
from matplotlib.pyplot import figure


df3=df.groupby(2).count()
df3.head()
myplot=df3.plot(kind="bar",figsize=(20,10))
myplot.grid()
myplot.set_title("Nº películes segons segons any")
myplot.text(10,-50,"Aquest gràfic permet veure com ha evolucionat el númeo de películes produïdes segons l'any",bbox = dict(facecolor = 'red', alpha = 0.5))
#myplot.plot()
plt.show()
